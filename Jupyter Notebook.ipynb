# %%
print("Hisssssss...")
# Out:
# Hisssssss...

# %%
print("¡Hola mundo!")
# Out:
# ¡Hola mundo!

# %%
print((2 ** 4), (2 * 4.), (2 * 4))
# Out:
# 16 8.0 8

# %%
a = '1'
b = "1"
print(a + b)

# %%
a = 6
b = 3
a /= 2 * b
print(a)
# Out:
# 1.0

# %%
counter = 5
while counter != 0:
    print("Dentro del bucle.", counter)
    counter -= 1
print("Fuera del bucle.", counter)
# Out:
# Dentro del bucle. 5
# Dentro del bucle. 4
# Dentro del bucle. 3
# Dentro del bucle. 2
# Dentro del bucle. 1
# Fuera del bucle. 0

# %%
print("\nLa instrucción continue:")
for i in range(1, 6):
    if i == 9:
        continue
    print("Dentro del bucle.", i)
print("Fuera del bucle.")
# Out:
# La instrucción continue:
# Dentro del bucle. 1
# Dentro del bucle. 2
# Dentro del bucle. 3
# Dentro del bucle. 4
# Dentro del bucle. 5
# Fuera del bucle.

# %%
print("Prueba Git Graph")
# Out:
# Prueba Git Graph

# %%
# Almacena el actual número más grande aquí.
largest_number = -999999999

# Ingresa el primer valor.
number = int(input("Introduce un número o escribe -1 para detener: "))

# Si el número no es igual a -1, continuaremos
while number != -1:
    # ¿Es el número más grande que el valor de largest_number?
    if number > largest_number:
        # Sí si, se actualiza largest_number.
        largest_number = number
    # Ingresa el siguiente número.
    number = int(input("Introduce un número o escribe -1 para detener: "))

# Imprime el número más grande.
print("El número más grande es:", largest_number)
# Out:
# El número más grande es: -999999999

# %%
# Un programa que lee una secuencia de números
# y cuenta cuántos números son pares y cuántos son impares.
# El programa termina cuando se ingresa un cero.

odd_numbers = 0
even_numbers = 0

# Lee el primer número.
number = int(input("Introduce un número o escribe 0 para detener: "))

# 0 termina la ejecución.
while number != 0:
    # Verificar si el número es impar.
    if number % 2 == 1:
        # Incrementar el contador de números impares odd_numbers.
        odd_numbers += 1
    else:
        # Incrementar el contador de números pares even_numbers.
        even_numbers += 1
    # Leer el siguiente número.
    number = int(input("Introduce un número o escribe 0 para detener: "))

# Imprimir resultados.
print("Conteo de números impares:", odd_numbers)
print("Conteo de números pares:", even_numbers)
# Out:
# Conteo de números impares: 2
# Conteo de números pares: 4

# %%
counter = 5
while counter != 0:
    print("Dentro del bucle.", counter)
    counter -= 1
print("Fuera del bucle.", counter)
# Out:
# Dentro del bucle. 5
# Dentro del bucle. 4
# Dentro del bucle. 3
# Dentro del bucle. 2
# Dentro del bucle. 1
# Fuera del bucle. 0

# %%
counter = 5
while counter:
    print("Dentro del bucle.", counter)
    counter -= 1
print("Fuera del bucle.", counter)
# Out:
# Dentro del bucle. 5
# Dentro del bucle. 4
# Dentro del bucle. 3
# Dentro del bucle. 2
# Dentro del bucle. 1
# Fuera del bucle. 0

# %%
palabra_secreta = "chupacabras"

palabra_secreta = (input("Introduce la palabra secreta: "))

# Si el número no es igual a -1, continuaremos
while palabra_secreta != "chupacabras":
    
    palabra_secreta = (input("Palabra secreta incorrecta, vuelva a intentar: "))

# Imprime el número más grande.
print("¡La palabra secreta es correcta!:", palabra_secreta)
# Out:
# ¡La palabra secreta es correcta!: chupacabras

# %%
import time

# El bucle for cuenta del 1 al 5
for i in range(1, 6):
    # Imprime el número de iteración y la palabra "Mississippi"
    print(i, "Mississippi")
    
    # Pausa el programa por 1 segundo
    time.sleep(1)

# Mensaje final fuera del bucle
print("¡Listos o no, ahí voy!")
# Out:
# 1 Mississippi
# 2 Mississippi
# 3 Mississippi
# 4 Mississippi
# 5 Mississippi
# ¡Listos o no, ahí voy!

# %%
# break - ejemplo

print("La instrucción break:")
for i in range(1, 6):
    if i == 3:
        break
    print("Dentro del bucle.", i)
print("Fuera del bucle.")


# continue - ejemplo

print("\nLa instrucción continue:")
for i in range(1, 6):
    if i == 3:
        continue
    print("Dentro del bucle.", i)
print("Fuera del bucle.")
# Out:
# La instrucción break:
# Dentro del bucle. 1
# Dentro del bucle. 2
# Fuera del bucle.
#
# La instrucción continue:
# Dentro del bucle. 1
# Dentro del bucle. 2
# Dentro del bucle. 4
# Dentro del bucle. 5
# Fuera del bucle.

# %%
largest_number = -99999999
counter = 0

while True:
    number = int(input("Ingresa un número o escribe -1 para finalizar el programa: "))
    if number == -1:
        break
    counter += 1
    if number > largest_number:
        largest_number = number

if counter != 0:
    print("El número más grande es", largest_number)
else:
    print("No has ingresado ningún número.")
# Out:
# El número más grande es 4

# %%
largest_number = -99999999
counter = 0

number = int(input("Ingresa un número o escribe -1 para finalizar el programa: "))

while number != -1:
    if number == -1:
        continue
    counter += 1

    if number > largest_number:
        largest_number = number
    number = int(input("Ingresa un número o escribe -1 para finalizar el programa: "))

if counter:
    print("El número más grande es", largest_number)
else:
    print("No has ingresado ningún número.")
# Out:
# El número más grande es 4

# %%
# Paso 1: Pedir al usuario que ingrese una palabra
user_word = input("Ingresa una palabra: ")

# Paso 2: Convertir la palabra a mayúsculas
user_word = user_word.upper()

# Paso 3: Usar un bucle for para iterar sobre cada letra
for letter in user_word:
    # Paso 4: Ejecución condicional para identificar las vocales
    if letter == "A":
        continue
    elif letter == "E":
        continue
    elif letter == "I":
        continue
    elif letter == "O":
        continue
    elif letter == "U":
        continue
    else:
        # Paso 5: Imprimir las letras no consumidas
        print(letter)
# Out:
# H
# L

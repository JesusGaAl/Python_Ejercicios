# %%
#Uso de la funcion de impresion en python
print("Hisssssss...")

# %%
#Otro ejemplo de impresion en python
print("¡Hola mundo!")

# %%
#Ejemplo que muestra la multiplicacion de numeros
print((2 ** 4), (2 * 4.), (2 * 4))

# %%
#Ejemplo de como interpreta python los caracteres entre comillas
a = '1'
b = "1"
print(a + b)

# %%
#Ejemplo que muetra el orden de prioridad de opreaciones en python
a = 6
b = 3
a /= 2 * b
print(a)

# %%
#Uso del ciclo de repeticion while
counter = 5
while counter != 0:
    print("Dentro del bucle.", counter)
    counter -= 1
print("Fuera del bucle.", counter)

# %%
#Ejemplo de ciclo while y continue
print("\nLa instrucción continue:")
for i in range(1, 6):
    if i == 9:
        continue
    print("Dentro del bucle.", i)
print("Fuera del bucle.")

# %%
#Ejemplo de programa que pide al usuario varios numero y al finalizar le muestra al 
#usuario el numero mas grande ingresado
# Almacena el actual número más grande aquí
largest_number = -999999999

# Ingresa el primer valor.
number = int(input("Introduce un número o escribe -1 para detener: "))

# Si el número no es igual a -1, continuaremos
while number != -1:
    # ¿Es el número más grande que el valor de largest_number?
    if number > largest_number:
        # Sí si, se actualiza largest_number.
        largest_number = number
    # Ingresa el siguiente número.
    number = int(input("Introduce un número o escribe -1 para detener: "))

# Imprime el número más grande.
print("El número más grande es:", largest_number)

# %%
# Un programa que lee una secuencia de números
# y cuenta cuántos números son pares y cuántos son impares
# El programa termina cuando se ingresa un cero

odd_numbers = 0
even_numbers = 0

# Lee el primer número.
number = int(input("Introduce un número o escribe 0 para detener: "))

# 0 termina la ejecución.
while number != 0:
    # Verificar si el número es impar.
    if number % 2 == 1:
        # Incrementar el contador de números impares odd_numbers.
        odd_numbers += 1
    else:
        # Incrementar el contador de números pares even_numbers.
        even_numbers += 1
    # Leer el siguiente número.
    number = int(input("Introduce un número o escribe 0 para detener: "))

# Imprimir resultados.
print("Conteo de números impares:", odd_numbers)
print("Conteo de números pares:", even_numbers)

# %%
#Imprimiendo numeros del 1 al 5 usando el bucle while
counter = 5
while counter != 0:
    print("Dentro del bucle.", counter)
    counter -= 1
print("Fuera del bucle.", counter)

# %%
#Imprimiendo numeros del 1 al 5 usando el bucle while
counter = 5
while counter:
    print("Dentro del bucle.", counter)
    counter -= 1
print("Fuera del bucle.", counter)

# %%
#Programa que pide al usuario una palabra y termina hasta que el usuario
#ingresa la palabra secreta
palabra_secreta = "chupacabras"
palabra_secreta = (input("Introduce la palabra secreta: "))

# Si el número no es igual a -1, continuaremos
while palabra_secreta != "chupacabras":
    
    palabra_secreta = (input("Palabra secreta incorrecta, vuelva a intentar: "))

# Imprime el número más grande.
print("¡La palabra secreta es correcta!:", palabra_secreta)

# %%
# El bucle for cuenta del 1 al 5
import time
for i in range(1, 6):
    # Imprime el número de iteración y la palabra "Mississippi"
    print(i, "Mississippi")
    
    # Pausa el programa por 1 segundo
    time.sleep(1)

# Mensaje final fuera del bucle
print("¡Listos o no, ahí voy!")

# %%
# break - ejemplo 

print("La instrucción break:")
for i in range(1, 6):
    if i == 3:
        break
    print("Dentro del bucle.", i)
print("Fuera del bucle.")


# continue - ejemplo 

print("\nLa instrucción continue:")
for i in range(1, 6):
    if i == 3:
        continue
    print("Dentro del bucle.", i)
print("Fuera del bucle.")

# %%
# Un programa que lee una secuencia de números
# y cuenta cuántos números son pares y cuántos son impares
# El programa termina cuando se ingresa un cero

largest_number = -99999999
counter = 0

while True:
    number = int(input("Ingresa un número o escribe -1 para finalizar el programa: "))
    if number == -1:
        break
    counter += 1
    if number > largest_number:
        largest_number = number

if counter != 0:
    print("El número más grande es", largest_number)
else:
    print("No has ingresado ningún número.")

# %%
#Programa que elimina las vocales de una palabra y las imprime de forma secuencial en mayusculas

# Paso 1: Pedir al usuario que ingrese una palabra
user_word = input("Ingresa una palabra: ")

# Paso 2: Convertir la palabra a mayúsculas
user_word = user_word.upper()

# Paso 3: Usar un bucle for para iterar sobre cada letra
for letter in user_word:
    # Paso 4: Ejecución condicional para identificar las vocales
    if letter == "A":
        continue
    elif letter == "E":
        continue
    elif letter == "I":
        continue
    elif letter == "O":
        continue
    elif letter == "U":
        continue
    else:
        # Paso 5: Imprimir las letras no consumidas
        print(letter)

# %%
#Programa que elimina las vocales de una palabra y las imprime de forma secuencial en mayusculas

# 1. Pedir al usuario que ingrese una palabra
user_word = input("Ingrese una palabra: ")

# 2. Convertir a mayúsculas
user_word = user_word.upper()

# 3. Crear la variable vacía para guardar el resultado
word_without_vowels = ""

# 4. Iniciar el bucle for para recorrer la palabra
for letter in user_word:
    # 5. Ejecución condicional con continue para "devorar" vocales
    if letter == "A":
        continue
    elif letter == "E":
        continue
    elif letter == "I":
        continue
    elif letter == "O":
        continue
    elif letter == "U":
        continue
    else:
        # 6. Si no es vocal, se concatena a nuestra nueva cadena
        word_without_vowels += letter

# 7. Imprimir el resultado final (fuera del bucle)
print(word_without_vowels)

# %%
#Programa que calcula la altura de una piramide de bloques, pone el doble de bloques en cada
#nivel empezando desde el nivel superior

# Paso 1: Leer la cantidad de bloques
bloques = int(input("Introduce el número de bloques: "))


altura = 0
bloques_necesarios = 1

# Paso 2: El bucle de construcción
while bloques >= bloques_necesarios:
    # Si entramos aquí, significa que podemos completar la capa
    bloques -= bloques_necesarios  # Gastamos los bloques
    altura += 1                    # Aumentamos la altura
    bloques_necesarios += 1        # La siguiente capa pedirá un bloque más

# Paso 3: Mostrar el resultado
print("La altura de la pirámide es:", altura)

# %%
#Programa que imprime las letras de una palabra separadas por *

# Ejemplo 1
word = "Python"
for letter in word:
    print(letter, end="*")

# %%
#Ejemplo que imprime los numeros del 1 al 9 que son pares.

# Ejemplo 2 corregido
for i in range(1, 10):
    if i % 2 == 0:
        print(i)  # Se eliminó el "print" extra

# %%
#Ejemplo que imprime las letras de una palabra hasta que encuentra la letra P, que es cuando se
#detiene

text = "OpenEDG Python Institute"
for letter in text:
    if letter == "P":
        break
    print(letter, end="")

# %%
#Ejemplo que imprime una palabra eliminando una determinada letra de ella.

text = "pyxpyxpyx"
for letter in text:
    if letter == "x":
        continue
    print(letter, end="")

# %%
#Ejemplo de bucle while que imprime ua secuencia de numeros

n = 0

while n != 3:
    print(n)
    n += 1
else:
    print(n, "else")

# %%
#Ejemplo de bucle while que imprime ua secuencia de numeros

n = 0

while n != 3:
    print(n)
    n += 1
else:
    print(n, "else")

print()

#Ejemplo de bucle while que imprime ua secuencia de numeros

for i in range(0, 3):
    print(i)
else:

    print(i, "else")

# %%
#Ejemplo de bucle regresivo de 6 a 1, debe ir disminuyendo 2(Noincluye el 1)

for i in range(6, 1, -2):
    print(i, end=" ")  # output: 6, 4, 2

# %%
#Ejemplo de blucle for, imprime los numeros impares del 1 al 11(No imprime el 11)

for i in range(1, 11):
    if i % 2 != 0:
        print(i)  # Se eliminó el "print" extra

# %%
#Ejemplo que interrupe la impresion de las letras de una palabra cuando encuentra la @

for ch in "john.smith@pythoninstitute.org":
    if ch == "@":
        break
    print(ch, end="")

# %%
#Programa que quita la @ de un correo electronico.
for digit in "john.smith@pythoninstitute.org":
    if digit == "@":
        # Línea de código.
        continue
        # Línea de código.
    # Línea de código. 
    print(digit,end="")

# %%
#Ejemplo que sistituye los 0s de una cadena de numeros por x

for digit in "0165031806510":
    if digit == "0":
        digit = "x"
    print(digit,end="")

# %%
#Ejemplo que sistituye los 0s de una cadena de numeros por x usando for y continue

for digit in "0165031806510":
    if digit == "0":
        print("x", end="")
        continue
    print(digit, end="")

# %%
#Imprime una cadena de numeros restando un numero en cada ciclo(uso de "numero virtual")

n = 3
while n > 0:
    print(n + 1)
    n -= 1
else:
    print(n)

# %%
#Ejemplo que imprime numeros desde -1 a 3 usando el ciclo for

n = range(4)
 
for num in n:
    print(num - 1)
else:
    print(num)

# %%
#Ejemplo que imprime numeros del 0 al 6 en pasos de 3 sin imprimir el 6

for i in range(0, 6, 3):
    print(i)

# %%
#Expresiones logicas

var = 1
# Ejemplo 1:
print(var > 0)
print(not (var <= 0))


# Ejemplo 2:
print(var != 0)
print(not (var == 0))

# %%
#Ejemplo de listas en python

numbers = [10, 5, 7, 2, 1]
print("Contenido de la lista:", numbers)  # Imprimiendo contenido de la lista original.

#Remplazando el elemento de indice 0 con 111:
numbers[0] = 111
print("Nuevo contenido de la lista: ", numbers)  # Contenido actual de la lista.

# %%
numbers = [10, 5, 7, 2, 1]
print("Contenido de la lista original:", numbers)  # Imprimiendo contenido de la lista original.

numbers[0] = 111
print("\nPrevio contenido de la lista:", numbers)  # Imprimiendo contenido de la lista anterior.

numbers[1] = numbers[4]  # Copiando el valor del quinto elemento al segundo elemento.
print("Nuevo contenido de la lista:", numbers)  # Imprimiendo el contenido de la lista actual.

# %%
#Compelmentando el ejercicio de listas con la istruccion para determinar el numero de elementos en una lista.

numbers = [10, 5, 7, 2, 1]
print("Contenido de la lista original:", numbers)  # Imprimiendo el contenido de la lista original.

numbers[0] = 111
print("\nContenido de la lista con cambio:", numbers)  # Imprimiendo contenido de la lista con 111.

numbers[1] = numbers[4]  # Copiando el valor del quinto elemento al segundo elemento.
print("Contenido de la lista con intercambio:", numbers)  # Imprimiendo contenido de la lista con intercambio.

print("\nLongitud de la lista:", len(numbers))  # Imprimiendo la longitud de la lista.

# %%
#Ejemplo que muestra el acceso rapido a los ultimos elementos de una lista

numbers = [111, 7, 2, 1]
print(numbers[-1])
print(numbers[-2])

# %%
#Ejemplo de reemplzaso de elementos en una lista por parte del usuario
hat_list = [1, 2, 3, 4, 5]  # Esta es una lista existente de números ocultos en el sombrero.
# Paso 1: escribe una línea de código que solicite al usuario
# reemplazar el número de en medio con un número entero ingresado por el usuario.
hat_list[2] = input("Ingrese un numero para reemplzar el numero central de la lista:")
# Paso 2: escribe aquí una línea de código que elimine el último elemento de la lista.
del hat_list[-1] 
# Paso 3: escribe aquí una línea de código que imprima la longitud de la lista existente.
print("La longitud de la lista es de:", len(hat_list))
print(hat_list)

# %%
#Ejemplo para insertar elementos dentro de una lista
numbers = [111, 7, 2, 1]
print(len(numbers))
print(numbers)

###

numbers.append(4)

print(len(numbers))
print(numbers)

###

numbers.insert(0, 222)
print(len(numbers))
print(numbers)

#

# %%
#Crear una lista vacia y agregar elementos mediante un for
my_list = []  # Creando una lista vacía.

for i in range(5):
    my_list.append(i + 1)

print(my_list)

# %%
#Crear una lista vacia y agregar elementos mediante el ciclo for y el metodo append y insert
my_list = []  # Creando una lista vacía.

for i in range(5):
    my_list.append(i + 1)

print(my_list)

#####################
my_list = []  # Creando una lista vacía.

for i in range(5):
    my_list.insert(0, i + 1)

print(my_list)
# Out:
# [1, 2, 3, 4, 5]
# [5, 4, 3, 2, 1]

# %%
#Suma del total de todos los numeros dentro de la lista
#Uso de range y len
my_list = [10, 1, 8, 3, 5]
total = 0

for i in range(len(my_list)):
    total += my_list[i]

print(total)

###############
#Uso de for
my_list = [10, 1, 8, 3, 5]
total = 0

for i in my_list:
    total += i

print(total)
# Out:
# 27
# 27

# %%
#Cambiando el valor de las variables en las variables sin perder el valor
variable_1 = 1
variable_2 = 2
print("Variable 1:",variable_1, "variable 2:", variable_2)
variable_1, variable_2 = variable_2, variable_1
print("Variable 1:",variable_1, "variable 2:", variable_2)
# Out:
# Variable 1: 1 variable 2: 2
# Variable 1: 2 variable 2: 1

# %%
#Ejemplo cambio de valores en listas
my_list = [10, 1, 8, 3, 5]
print("Valores en la lista antes del cambio:",my_list)
my_list[0], my_list[4] = my_list[4], my_list[0]
my_list[1], my_list[3] = my_list[3], my_list[1]
print("Valores en la lista antes del cambio:",my_list)
# Out:
# Valores en la lista antes del cambio: [10, 1, 8, 3, 5]
# Valores en la lista antes del cambio: [5, 3, 8, 1, 10]
